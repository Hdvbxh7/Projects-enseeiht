# %% [markdown]
# <center>
# <h1> TP-Projet d'optimisation numérique </h1>
# <h1> Algorithme du lagrangien augmenté </h1>
# </center>

# %% [markdown]
# ## Implémentation
#
# 1. Implémenter l'algorithme du lagrangien augmenté, en utilisant les différentes méthodes
# qui ont été vues en première partie pour la résolution de la suite de problèmes sans
# contraintes (fichier `src/lagrangien_augmente.jl`). La spécification est donnée dans le fichier.
# 2. Vérifier que les tests ci-dessous passent.

# %%
include("../src/lagrangien_augmente.jl")
include("../test/tester_lagrangien_augmente.jl")

#
afficher = false # si true, alors affiche les résultats des algorithmes

#
tester_lagrangien_augmente(lagrangien_augmente, afficher);
# Out:
# Affichage des résultats des algorithmes : false
#
# Avec newton: Error During Test at /home/tgz8009/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#   Got exception outside of a @test
#   MethodError: no method matching size(::typeof(contrainte1), ::Int64)
#   Closest candidates are:
#     size(::Union{QR, LinearAlgebra.QRCompactWY, QRPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/qr.jl:580
#     size(::Union{Hermitian{T, S}, Symmetric{T, S}} where {T, S}, ::Any) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/symmetric.jl:203
#     size(::Union{Cholesky, CholeskyPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/cholesky.jl:515
#     ...
#   Stacktrace:
#     [1] lagrangien_augmente(f::typeof(fct1), gradf::typeof(grad_fct1), hessf::typeof(hess_fct1), c::typeof(contrainte1), gradc::typeof(grad_contrainte1), hessc::typeof(hess_contrainte1), x0::Vector{Int64}; max_iter::Int64, tol_abs::Float64, tol_rel::Float64, λ0::Int64, μ0::Int64, τ::Int64, algo_noc::String)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/src/lagrangien_augmente.jl:83
#     [2] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:51 [inlined]
#     [3] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1433 [inlined]
#     [4] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47 [inlined]
#     [5] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#     [6] tester_lagrangien_augmente(LA::typeof(lagrangien_augmente), afficher::Bool)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#     [7] top-level scope
#       @ In[11]:8
#     [8] eval
#       @ ./boot.jl:368 [inlined]
#     [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base ./loading.jl:1428
#    [10] softscope_include_string(m::Module, code::String, filename::String)
#       @ SoftGlobalScope /mnt/n7fs/ens/tp_cots/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
#    [11] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/execute_request.jl:67
#    [12] #invokelatest#2
#       @ ./essentials.jl:729 [inlined]
#    [13] invokelatest
#       @ ./essentials.jl:726 [inlined]
#    [14] eventloop(socket::ZMQ.Socket)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/eventloop.jl:8
#    [15] (::IJulia.var"#15#18")()
#       @ IJulia ./task.jl:484
# Avec rc-cauchy: Error During Test at /home/tgz8009/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#   Got exception outside of a @test
#   MethodError: no method matching size(::typeof(contrainte1), ::Int64)
#   Closest candidates are:
#     size(::Union{QR, LinearAlgebra.QRCompactWY, QRPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/qr.jl:580
#     size(::Union{Hermitian{T, S}, Symmetric{T, S}} where {T, S}, ::Any) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/symmetric.jl:203
#     size(::Union{Cholesky, CholeskyPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/cholesky.jl:515
#     ...
#   Stacktrace:
#     [1] lagrangien_augmente(f::typeof(fct1), gradf::typeof(grad_fct1), hessf::typeof(hess_fct1), c::typeof(contrainte1), gradc::typeof(grad_contrainte1), hessc::typeof(hess_contrainte1), x0::Vector{Int64}; max_iter::Int64, tol_abs::Float64, tol_rel::Float64, λ0::Int64, μ0::Int64, τ::Int64, algo_noc::String)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/src/lagrangien_augmente.jl:83
#     [2] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:51 [inlined]
#     [3] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1433 [inlined]
#     [4] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47 [inlined]
#     [5] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#     [6] tester_lagrangien_augmente(LA::typeof(lagrangien_augmente), afficher::Bool)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#     [7] top-level scope
#       @ In[11]:8
#     [8] eval
#       @ ./boot.jl:368 [inlined]
#     [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base ./loading.jl:1428
#    [10] softscope_include_string(m::Module, code::String, filename::String)
#       @ SoftGlobalScope /mnt/n7fs/ens/tp_cots/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
#    [11] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/execute_request.jl:67
#    [12] #invokelatest#2
#       @ ./essentials.jl:729 [inlined]
#    [13] invokelatest
#       @ ./essentials.jl:726 [inlined]
#    [14] eventloop(socket::ZMQ.Socket)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/eventloop.jl:8
#    [15] (::IJulia.var"#15#18")()
#       @ IJulia ./task.jl:484
# Avec rc-gct: Error During Test at /home/tgz8009/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#   Got exception outside of a @test
#   MethodError: no method matching size(::typeof(contrainte1), ::Int64)
#   Closest candidates are:
#     size(::Union{QR, LinearAlgebra.QRCompactWY, QRPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/qr.jl:580
#     size(::Union{Hermitian{T, S}, Symmetric{T, S}} where {T, S}, ::Any) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/symmetric.jl:203
#     size(::Union{Cholesky, CholeskyPivoted}, ::Integer) at /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/LinearAlgebra/src/cholesky.jl:515
#     ...
#   Stacktrace:
#     [1] lagrangien_augmente(f::typeof(fct1), gradf::typeof(grad_fct1), hessf::typeof(hess_fct1), c::typeof(contrainte1), gradc::typeof(grad_contrainte1), hessc::typeof(hess_contrainte1), x0::Vector{Int64}; max_iter::Int64, tol_abs::Float64, tol_rel::Float64, λ0::Int64, μ0::Int64, τ::Int64, algo_noc::String)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/src/lagrangien_augmente.jl:83
#     [2] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:51 [inlined]
#     [3] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1433 [inlined]
#     [4] macro expansion
#       @ ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47 [inlined]
#     [5] macro expansion
#       @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1357 [inlined]
#     [6] tester_lagrangien_augmente(LA::typeof(lagrangien_augmente), afficher::Bool)
#       @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#     [7] top-level scope
#       @ In[11]:8
#     [8] eval
#       @ ./boot.jl:368 [inlined]
#     [9] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#       @ Base ./loading.jl:1428
#    [10] softscope_include_string(m::Module, code::String, filename::String)
#       @ SoftGlobalScope /mnt/n7fs/ens/tp_cots/.julia/packages/SoftGlobalScope/u4UzH/src/SoftGlobalScope.jl:65
#    [11] execute_request(socket::ZMQ.Socket, msg::IJulia.Msg)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/execute_request.jl:67
#    [12] #invokelatest#2
#       @ ./essentials.jl:729 [inlined]
#    [13] invokelatest
#       @ ./essentials.jl:726 [inlined]
#    [14] eventloop(socket::ZMQ.Socket)
#       @ IJulia /mnt/n7fs/ens/tp_cots/.julia/packages/IJulia/6TIq1/src/eventloop.jl:8
#    [15] (::IJulia.var"#15#18")()
#       @ IJulia ./task.jl:484
# Test Summary:         | Error  Total  Time
# Lagrangien augmenté   |     3      3  0.1s
#   Avec newton         |     1      1  0.0s
#   Avec rc-cauchy      |     1      1  0.0s
#   Avec rc-gct         |     1      1  0.0s
# Some tests did not pass: 0 passed, 0 failed, 3 errored, 0 broken.
#
# Stacktrace:
#  [1] finish(ts::Test.DefaultTestSet)
#    @ Test /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1092
#  [2] macro expansion
#    @ /mnt/n7fs/ens/tp_cots/julia-1.8.2/share/julia/stdlib/v1.8/Test/src/Test.jl:1368 [inlined]
#  [3] tester_lagrangien_augmente(LA::typeof(lagrangien_augmente), afficher::Bool)
#    @ Main ~/projetmaj/Projects-enseeiht/optinum/projet-optinum-master/test/tester_lagrangien_augmente.jl:47
#  [4] top-level scope
#    @ In[11]:8

# %% [markdown]
# ## Interprétation
#
#  1. Commenter les résultats obtenus, en étudiant notamment les valeurs en sortie de $\lambda_k$ et $\mu_k$.
#  2. Étudier l'influence du paramètre $\tau$ dans la performance de l'algorithme. Pour cela Vous réaliserez des tests numériques.

# %%
# Expérimentations numériques à faire ici.
# Vous pouvez utiliser le package Plots pour les affichages de courbes: using Plots
